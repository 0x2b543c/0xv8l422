# %%
import sys
import pandas as pd
# %matplotlib inline
sys.path.append('/workspace')
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

# %%
from modules.Visualizers.LineChart import LineChart
from modules.DataLoaders.CM_API import CM_API

# %%
api_key = 'KKzV6V2DTY87v3m1dGZu'
assets = ['btc', 'eth']
start = '2019-01-01'

# %%
asset_info = CM_API().get_coinmetrics_discovery_asset_info(api_key=api_key)

# %%
btc_asset_info = [asset for asset in asset_info['assetsInfo'] if asset['id'] == 'btc'][0]

# %%
# df = CM_API().get_coinmetrics_candles_data(api_key=api_key, market_idassets=assets, start=None)

# %%
btc_asset_info
# Out:
# {'id': 'btc',
#  'name': 'Bitcoin',
#  'metrics': ['AdrActCnt',
#   'AdrActRecCnt',
#   'AdrActSentCnt',
#   'AdrBal1in100KCnt',
#   'AdrBal1in100MCnt',
#   'AdrBal1in10BCnt',
#   'AdrBal1in10KCnt',
#   'AdrBal1in10MCnt',
#   'AdrBal1in1BCnt',
#   'AdrBal1in1KCnt',
#   'AdrBal1in1MCnt',
#   'AdrBalCnt',
#   'AdrBalNtv0.001Cnt',
#   'AdrBalNtv0.01Cnt',
#   'AdrBalNtv0.1Cnt',
#   'AdrBalNtv100Cnt',
#   'AdrBalNtv100KCnt',
#   'AdrBalNtv10Cnt',
#   'AdrBalNtv10KCnt',
#   'AdrBalNtv1Cnt',
#   'AdrBalNtv1KCnt',
#   'AdrBalNtv1MCnt',
#   'AdrBalUSD100Cnt',
#   'AdrBalUSD100KCnt',
#   'AdrBalUSD10Cnt',
#   'AdrBalUSD10KCnt',
#   'AdrBalUSD10MCnt',
#   'AdrBalUSD1Cnt',
#   'AdrBalUSD1KCnt',
#   'AdrBalUSD1MCnt',
#   'AdrCnt',
#   'BlkCnt',
#   'BlkHgt',
#   'BlkIntMean',
#   'BlkSizeByte',
#   'BlkSizeMeanByte',
#   'BlkUncCnt',
#   'BlkUncRwd',
#   'BlkUncRwdUSD',
#   'BlkWghtMean',
#   'CapAct1yrUSD',
#   'CapFutExp10yrUSD',
#   'CapMVRVCur',
#   'CapMrktCurUSD',
#   'CapRealUSD',
# ...
